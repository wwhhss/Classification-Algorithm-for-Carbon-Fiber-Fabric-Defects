# %% [markdown]
# # MobileNetV3-Large
#
# Unified four-class training and evaluation.

# %%
from ml_experiments import TorchConfig, run_torch_experiment

# %%
config = TorchConfig(
    model_name='mobilenet_v3_large',
    checkpoint='MobileNetV3.pth',
    epochs=100,
    freeze_backbone=True,
)
result = run_torch_experiment(config)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_large-5c1a4163.pth" to C:\Users\WHS/.cache\torch\hub\checkpoints\mobilenet_v3_large-5c1a4163.pth
#   0%|          | 0.00/21.1M [00:00<?, ?B/s]
# mobilenet_v3_large: epoch 1/100 | train_acc=0.227 | val_acc=0.261
# mobilenet_v3_large: epoch 2/100 | train_acc=0.320 | val_acc=0.275
# mobilenet_v3_large: epoch 3/100 | train_acc=0.424 | val_acc=0.342
# mobilenet_v3_large: epoch 4/100 | train_acc=0.498 | val_acc=0.392
# mobilenet_v3_large: epoch 5/100 | train_acc=0.556 | val_acc=0.419
# mobilenet_v3_large: epoch 6/100 | train_acc=0.620 | val_acc=0.468
# mobilenet_v3_large: epoch 7/100 | train_acc=0.641 | val_acc=0.491
# mobilenet_v3_large: epoch 8/100 | train_acc=0.669 | val_acc=0.505
# mobilenet_v3_large: epoch 9/100 | train_acc=0.665 | val_acc=0.527
# mobilenet_v3_large: epoch 10/100 | train_acc=0.698 | val_acc=0.541
# mobilenet_v3_large: epoch 11/100 | train_acc=0.692 | val_acc=0.545
# mobilenet_v3_large: epoch 12/100 | train_acc=0.717 | val_acc=0.559
# mobilenet_v3_large: epoch 13/100 | train_acc=0.729 | val_acc=0.590
# mobilenet_v3_large: epoch 14/100 | train_acc=0.719 | val_acc=0.617
# mobilenet_v3_large: epoch 15/100 | train_acc=0.752 | val_acc=0.613
# mobilenet_v3_large: epoch 16/100 | train_acc=0.760 | val_acc=0.622
# mobilenet_v3_large: epoch 17/100 | train_acc=0.762 | val_acc=0.626
# mobilenet_v3_large: epoch 18/100 | train_acc=0.775 | val_acc=0.626
# mobilenet_v3_large: epoch 19/100 | train_acc=0.740 | val_acc=0.635
# mobilenet_v3_large: epoch 20/100 | train_acc=0.750 | val_acc=0.631
# mobilenet_v3_large: epoch 21/100 | train_acc=0.783 | val_acc=0.631
# mobilenet_v3_large: epoch 22/100 | train_acc=0.781 | val_acc=0.622
# mobilenet_v3_large: epoch 23/100 | train_acc=0.791 | val_acc=0.608
# mobilenet_v3_large: epoch 24/100 | train_acc=0.781 | val_acc=0.604
# mobilenet_v3_large: epoch 25/100 | train_acc=0.762 | val_acc=0.617
# mobilenet_v3_large: epoch 26/100 | train_acc=0.797 | val_acc=0.613
# mobilenet_v3_large: epoch 27/100 | train_acc=0.760 | val_acc=0.608
# mobilenet_v3_large: epoch 28/100 | train_acc=0.798 | val_acc=0.604
# mobilenet_v3_large: epoch 29/100 | train_acc=0.777 | val_acc=0.604
# mobilenet_v3_large: epoch 30/100 | train_acc=0.775 | val_acc=0.608
# mobilenet_v3_large: epoch 31/100 | train_acc=0.783 | val_acc=0.626
# mobilenet_v3_large: epoch 32/100 | train_acc=0.789 | val_acc=0.649
# mobilenet_v3_large: epoch 33/100 | train_acc=0.837 | val_acc=0.644
# mobilenet_v3_large: epoch 34/100 | train_acc=0.773 | val_acc=0.649
# mobilenet_v3_large: epoch 35/100 | train_acc=0.798 | val_acc=0.653
# mobilenet_v3_large: epoch 36/100 | train_acc=0.826 | val_acc=0.658
# mobilenet_v3_large: epoch 37/100 | train_acc=0.798 | val_acc=0.653
# mobilenet_v3_large: epoch 38/100 | train_acc=0.824 | val_acc=0.662
# mobilenet_v3_large: epoch 39/100 | train_acc=0.798 | val_acc=0.671
# mobilenet_v3_large: epoch 40/100 | train_acc=0.785 | val_acc=0.676
# mobilenet_v3_large: epoch 41/100 | train_acc=0.820 | val_acc=0.680
# mobilenet_v3_large: epoch 42/100 | train_acc=0.820 | val_acc=0.685
# mobilenet_v3_large: epoch 43/100 | train_acc=0.818 | val_acc=0.689
# mobilenet_v3_large: epoch 44/100 | train_acc=0.812 | val_acc=0.680
# mobilenet_v3_large: epoch 45/100 | train_acc=0.828 | val_acc=0.689
# mobilenet_v3_large: epoch 46/100 | train_acc=0.847 | val_acc=0.685
# mobilenet_v3_large: epoch 47/100 | train_acc=0.835 | val_acc=0.689
# mobilenet_v3_large: epoch 48/100 | train_acc=0.812 | val_acc=0.685
# mobilenet_v3_large: epoch 49/100 | train_acc=0.820 | val_acc=0.689
# mobilenet_v3_large: epoch 50/100 | train_acc=0.816 | val_acc=0.698
# mobilenet_v3_large: epoch 51/100 | train_acc=0.824 | val_acc=0.698
# mobilenet_v3_large: epoch 52/100 | train_acc=0.829 | val_acc=0.707
# mobilenet_v3_large: epoch 53/100 | train_acc=0.845 | val_acc=0.716
# mobilenet_v3_large: epoch 54/100 | train_acc=0.831 | val_acc=0.725
# mobilenet_v3_large: epoch 55/100 | train_acc=0.831 | val_acc=0.739
# mobilenet_v3_large: epoch 56/100 | train_acc=0.835 | val_acc=0.739
# mobilenet_v3_large: epoch 57/100 | train_acc=0.828 | val_acc=0.748
# mobilenet_v3_large: epoch 58/100 | train_acc=0.820 | val_acc=0.757
# mobilenet_v3_large: epoch 59/100 | train_acc=0.872 | val_acc=0.752
# mobilenet_v3_large: epoch 60/100 | train_acc=0.824 | val_acc=0.766
# mobilenet_v3_large: epoch 61/100 | train_acc=0.818 | val_acc=0.779
# mobilenet_v3_large: epoch 62/100 | train_acc=0.855 | val_acc=0.784
# mobilenet_v3_large: epoch 63/100 | train_acc=0.847 | val_acc=0.802
# mobilenet_v3_large: epoch 64/100 | train_acc=0.808 | val_acc=0.811
# mobilenet_v3_large: epoch 65/100 | train_acc=0.824 | val_acc=0.820
# mobilenet_v3_large: epoch 66/100 | train_acc=0.829 | val_acc=0.815
# mobilenet_v3_large: epoch 67/100 | train_acc=0.824 | val_acc=0.820
# mobilenet_v3_large: epoch 68/100 | train_acc=0.845 | val_acc=0.829
# mobilenet_v3_large: epoch 69/100 | train_acc=0.824 | val_acc=0.833
# mobilenet_v3_large: epoch 70/100 | train_acc=0.835 | val_acc=0.842
# mobilenet_v3_large: epoch 71/100 | train_acc=0.824 | val_acc=0.842
# mobilenet_v3_large: epoch 72/100 | train_acc=0.855 | val_acc=0.838
# mobilenet_v3_large: epoch 73/100 | train_acc=0.866 | val_acc=0.838
# mobilenet_v3_large: epoch 74/100 | train_acc=0.839 | val_acc=0.851
# mobilenet_v3_large: epoch 75/100 | train_acc=0.845 | val_acc=0.856
# mobilenet_v3_large: epoch 76/100 | train_acc=0.826 | val_acc=0.869
# mobilenet_v3_large: epoch 77/100 | train_acc=0.835 | val_acc=0.874
# mobilenet_v3_large: epoch 78/100 | train_acc=0.839 | val_acc=0.887
# mobilenet_v3_large: epoch 79/100 | train_acc=0.851 | val_acc=0.887
# mobilenet_v3_large: epoch 80/100 | train_acc=0.862 | val_acc=0.887
# mobilenet_v3_large: epoch 81/100 | train_acc=0.860 | val_acc=0.887
# mobilenet_v3_large: epoch 82/100 | train_acc=0.833 | val_acc=0.887
# mobilenet_v3_large: epoch 83/100 | train_acc=0.837 | val_acc=0.896
# mobilenet_v3_large: epoch 84/100 | train_acc=0.857 | val_acc=0.901
# mobilenet_v3_large: epoch 85/100 | train_acc=0.886 | val_acc=0.896
# mobilenet_v3_large: epoch 86/100 | train_acc=0.826 | val_acc=0.901
# mobilenet_v3_large: epoch 87/100 | train_acc=0.855 | val_acc=0.905
# mobilenet_v3_large: epoch 88/100 | train_acc=0.857 | val_acc=0.905
# mobilenet_v3_large: epoch 89/100 | train_acc=0.866 | val_acc=0.905
# mobilenet_v3_large: epoch 90/100 | train_acc=0.860 | val_acc=0.910
# mobilenet_v3_large: epoch 91/100 | train_acc=0.862 | val_acc=0.919
# mobilenet_v3_large: epoch 92/100 | train_acc=0.860 | val_acc=0.914
# mobilenet_v3_large: epoch 93/100 | train_acc=0.837 | val_acc=0.914
# mobilenet_v3_large: epoch 94/100 | train_acc=0.845 | val_acc=0.919
# mobilenet_v3_large: epoch 95/100 | train_acc=0.829 | val_acc=0.910
# mobilenet_v3_large: epoch 96/100 | train_acc=0.864 | val_acc=0.914
# mobilenet_v3_large: epoch 97/100 | train_acc=0.857 | val_acc=0.928
# mobilenet_v3_large: epoch 98/100 | train_acc=0.820 | val_acc=0.928
# mobilenet_v3_large: epoch 99/100 | train_acc=0.853 | val_acc=0.923
# mobilenet_v3_large: epoch 100/100 | train_acc=0.862 | val_acc=0.923
# mobilenet_v3_large: parameters=4,207,156, accuracy=92.793%, training=1414.798s, classification=0.010033s/image

# %%
{key: result[key] for key in (
    'parameter_count',
    'accuracy_percent',
    'training_time_seconds',
    'classification_time_seconds_per_image',
)}
# Out:
# {'parameter_count': 4207156,
#  'accuracy_percent': 92.7927927927928,
#  'training_time_seconds': 1414.797713,
#  'classification_time_seconds_per_image': 0.010032991}
