# %% [markdown]
# # ResNet-50
#
# ResNet-50 ???????
#
# ??????????????????????????? `SMOKE_TEST=1`???????? `IMAGE_DATA_DIR` ???????????? `artifacts/`?

# %%
from ml_experiments import TorchConfig, run_torch_experiment

# %%
config = TorchConfig(
    model_name='resnet50',
    checkpoint='ResNet50.pth',
    epochs=100,
    freeze_backbone=False,
)
result = run_torch_experiment(config)

# %%
{key: value for key, value in result.items() if key != 'history'}
