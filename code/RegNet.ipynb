# %% [markdown]
# # RegNetY-400MF
#
# Unified four-class training and evaluation.

# %%
from ml_experiments import TorchConfig, run_torch_experiment

# %%
config = TorchConfig(
    model_name='regnet_y_400mf',
    checkpoint='RegNet.pth',
    epochs=100,
    freeze_backbone=True,
)
result = run_torch_experiment(config)
# Out:
# Downloading: "https://download.pytorch.org/models/regnet_y_400mf-e6988f5f.pth" to C:\Users\WHS/.cache\torch\hub\checkpoints\regnet_y_400mf-e6988f5f.pth
#   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# regnet_y_400mf: epoch 1/100 | train_acc=0.229 | val_acc=0.234
# regnet_y_400mf: epoch 2/100 | train_acc=0.298 | val_acc=0.320
# regnet_y_400mf: epoch 3/100 | train_acc=0.347 | val_acc=0.351
# regnet_y_400mf: epoch 4/100 | train_acc=0.419 | val_acc=0.446
# regnet_y_400mf: epoch 5/100 | train_acc=0.436 | val_acc=0.486
# regnet_y_400mf: epoch 6/100 | train_acc=0.457 | val_acc=0.500
# regnet_y_400mf: epoch 7/100 | train_acc=0.471 | val_acc=0.550
# regnet_y_400mf: epoch 8/100 | train_acc=0.531 | val_acc=0.541
# regnet_y_400mf: epoch 9/100 | train_acc=0.535 | val_acc=0.586
# regnet_y_400mf: epoch 10/100 | train_acc=0.583 | val_acc=0.604
# regnet_y_400mf: epoch 11/100 | train_acc=0.595 | val_acc=0.667
# regnet_y_400mf: epoch 12/100 | train_acc=0.587 | val_acc=0.662
# regnet_y_400mf: epoch 13/100 | train_acc=0.610 | val_acc=0.649
# regnet_y_400mf: epoch 14/100 | train_acc=0.610 | val_acc=0.653
# regnet_y_400mf: epoch 15/100 | train_acc=0.634 | val_acc=0.676
# regnet_y_400mf: epoch 16/100 | train_acc=0.624 | val_acc=0.676
# regnet_y_400mf: epoch 17/100 | train_acc=0.636 | val_acc=0.698
# regnet_y_400mf: epoch 18/100 | train_acc=0.620 | val_acc=0.667
# regnet_y_400mf: epoch 19/100 | train_acc=0.655 | val_acc=0.667
# regnet_y_400mf: epoch 20/100 | train_acc=0.674 | val_acc=0.703
# regnet_y_400mf: epoch 21/100 | train_acc=0.678 | val_acc=0.698
# regnet_y_400mf: epoch 22/100 | train_acc=0.669 | val_acc=0.703
# regnet_y_400mf: epoch 23/100 | train_acc=0.624 | val_acc=0.712
# regnet_y_400mf: epoch 24/100 | train_acc=0.667 | val_acc=0.707
# regnet_y_400mf: epoch 25/100 | train_acc=0.690 | val_acc=0.730
# regnet_y_400mf: epoch 26/100 | train_acc=0.682 | val_acc=0.743
# regnet_y_400mf: epoch 27/100 | train_acc=0.682 | val_acc=0.757
# regnet_y_400mf: epoch 28/100 | train_acc=0.702 | val_acc=0.734
# regnet_y_400mf: epoch 29/100 | train_acc=0.702 | val_acc=0.748
# regnet_y_400mf: epoch 30/100 | train_acc=0.715 | val_acc=0.766
# regnet_y_400mf: epoch 31/100 | train_acc=0.711 | val_acc=0.770
# regnet_y_400mf: epoch 32/100 | train_acc=0.717 | val_acc=0.757
# regnet_y_400mf: epoch 33/100 | train_acc=0.707 | val_acc=0.775
# regnet_y_400mf: epoch 34/100 | train_acc=0.734 | val_acc=0.757
# regnet_y_400mf: epoch 35/100 | train_acc=0.700 | val_acc=0.775
# regnet_y_400mf: epoch 36/100 | train_acc=0.709 | val_acc=0.784
# regnet_y_400mf: epoch 37/100 | train_acc=0.723 | val_acc=0.739
# regnet_y_400mf: epoch 38/100 | train_acc=0.734 | val_acc=0.779
# regnet_y_400mf: epoch 39/100 | train_acc=0.702 | val_acc=0.770
# regnet_y_400mf: epoch 40/100 | train_acc=0.719 | val_acc=0.770
# regnet_y_400mf: epoch 41/100 | train_acc=0.729 | val_acc=0.766
# regnet_y_400mf: epoch 42/100 | train_acc=0.719 | val_acc=0.730
# regnet_y_400mf: epoch 43/100 | train_acc=0.721 | val_acc=0.793
# regnet_y_400mf: epoch 44/100 | train_acc=0.694 | val_acc=0.752
# regnet_y_400mf: epoch 45/100 | train_acc=0.733 | val_acc=0.775
# regnet_y_400mf: epoch 46/100 | train_acc=0.746 | val_acc=0.793
# regnet_y_400mf: epoch 47/100 | train_acc=0.756 | val_acc=0.793
# regnet_y_400mf: epoch 48/100 | train_acc=0.713 | val_acc=0.779
# regnet_y_400mf: epoch 49/100 | train_acc=0.721 | val_acc=0.788
# regnet_y_400mf: epoch 50/100 | train_acc=0.725 | val_acc=0.784
# regnet_y_400mf: epoch 51/100 | train_acc=0.709 | val_acc=0.784
# regnet_y_400mf: epoch 52/100 | train_acc=0.738 | val_acc=0.797
# regnet_y_400mf: epoch 53/100 | train_acc=0.748 | val_acc=0.757
# regnet_y_400mf: epoch 54/100 | train_acc=0.754 | val_acc=0.802
# regnet_y_400mf: epoch 55/100 | train_acc=0.713 | val_acc=0.811
# regnet_y_400mf: epoch 56/100 | train_acc=0.760 | val_acc=0.833
# regnet_y_400mf: epoch 57/100 | train_acc=0.738 | val_acc=0.815
# regnet_y_400mf: epoch 58/100 | train_acc=0.764 | val_acc=0.766
# regnet_y_400mf: epoch 59/100 | train_acc=0.734 | val_acc=0.806
# regnet_y_400mf: epoch 60/100 | train_acc=0.740 | val_acc=0.802
# regnet_y_400mf: epoch 61/100 | train_acc=0.734 | val_acc=0.806
# regnet_y_400mf: epoch 62/100 | train_acc=0.769 | val_acc=0.806
# regnet_y_400mf: epoch 63/100 | train_acc=0.746 | val_acc=0.752
# regnet_y_400mf: epoch 64/100 | train_acc=0.733 | val_acc=0.815
# regnet_y_400mf: epoch 65/100 | train_acc=0.754 | val_acc=0.793
# regnet_y_400mf: epoch 66/100 | train_acc=0.758 | val_acc=0.788
# regnet_y_400mf: epoch 67/100 | train_acc=0.744 | val_acc=0.806
# regnet_y_400mf: epoch 68/100 | train_acc=0.802 | val_acc=0.811
# regnet_y_400mf: epoch 69/100 | train_acc=0.758 | val_acc=0.806
# regnet_y_400mf: epoch 70/100 | train_acc=0.789 | val_acc=0.784
# regnet_y_400mf: epoch 71/100 | train_acc=0.762 | val_acc=0.806
# regnet_y_400mf: epoch 72/100 | train_acc=0.750 | val_acc=0.784
# regnet_y_400mf: epoch 73/100 | train_acc=0.771 | val_acc=0.838
# regnet_y_400mf: epoch 74/100 | train_acc=0.744 | val_acc=0.815
# regnet_y_400mf: epoch 75/100 | train_acc=0.758 | val_acc=0.797
# regnet_y_400mf: epoch 76/100 | train_acc=0.760 | val_acc=0.856
# regnet_y_400mf: epoch 77/100 | train_acc=0.771 | val_acc=0.833
# regnet_y_400mf: epoch 78/100 | train_acc=0.754 | val_acc=0.811
# regnet_y_400mf: epoch 79/100 | train_acc=0.760 | val_acc=0.806
# regnet_y_400mf: epoch 80/100 | train_acc=0.766 | val_acc=0.833
# regnet_y_400mf: epoch 81/100 | train_acc=0.766 | val_acc=0.860
# regnet_y_400mf: epoch 82/100 | train_acc=0.767 | val_acc=0.833
# regnet_y_400mf: epoch 83/100 | train_acc=0.766 | val_acc=0.802
# regnet_y_400mf: epoch 84/100 | train_acc=0.771 | val_acc=0.806
# regnet_y_400mf: epoch 85/100 | train_acc=0.797 | val_acc=0.829
# regnet_y_400mf: epoch 86/100 | train_acc=0.779 | val_acc=0.824
# regnet_y_400mf: epoch 87/100 | train_acc=0.812 | val_acc=0.811
# regnet_y_400mf: epoch 88/100 | train_acc=0.779 | val_acc=0.829
# regnet_y_400mf: epoch 89/100 | train_acc=0.777 | val_acc=0.833
# regnet_y_400mf: epoch 90/100 | train_acc=0.773 | val_acc=0.842
# regnet_y_400mf: epoch 91/100 | train_acc=0.760 | val_acc=0.851
# regnet_y_400mf: epoch 92/100 | train_acc=0.760 | val_acc=0.820
# regnet_y_400mf: epoch 93/100 | train_acc=0.769 | val_acc=0.829
# regnet_y_400mf: epoch 94/100 | train_acc=0.791 | val_acc=0.829
# regnet_y_400mf: epoch 95/100 | train_acc=0.754 | val_acc=0.851
# regnet_y_400mf: epoch 96/100 | train_acc=0.748 | val_acc=0.793
# regnet_y_400mf: epoch 97/100 | train_acc=0.758 | val_acc=0.833
# regnet_y_400mf: epoch 98/100 | train_acc=0.808 | val_acc=0.851
# regnet_y_400mf: epoch 99/100 | train_acc=0.760 | val_acc=0.811
# regnet_y_400mf: epoch 100/100 | train_acc=0.789 | val_acc=0.806
# regnet_y_400mf: parameters=3,904,908, accuracy=86.036%, training=1345.929s, classification=0.014455s/image

# %%
{key: result[key] for key in (
    'parameter_count',
    'accuracy_percent',
    'training_time_seconds',
    'classification_time_seconds_per_image',
)}
# Out:
# {'parameter_count': 3904908,
#  'accuracy_percent': 86.03603603603604,
#  'training_time_seconds': 1345.92863,
#  'classification_time_seconds_per_image': 0.014454966}
