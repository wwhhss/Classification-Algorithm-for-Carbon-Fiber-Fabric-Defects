# %%
import os
import time
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, models, transforms
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from torch.utils.data import ConcatDataset
from sklearn.model_selection import train_test_split

# 记录开始时间
start_time = time.time()

# 定义超参数
batch_size = 64
learning_rate = 0.001
num_epochs = 100

data_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# 加载数据集
data_dir = 'C:/Users/WHS/Desktop/SVM-Image-Classification-master/images4'
image_datasets = datasets.ImageFolder(data_dir, data_transforms)

# 划分训练集和测试集
train_data, test_data = train_test_split(image_datasets, test_size=0.3, random_state=42)

dataloaders = {'train':torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True, num_workers=4),
               'val':torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=False, num_workers=4)}
dataset_sizes = {'train': len(train_data),'val': len(test_data)}

# %%
# 加载预训练模型
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 4)
device = torch.device('cuda:0')
model = model.to(device)

# 冻结前8个层
for param in model.conv1.parameters():
    param.requires_grad = False

for param in model.bn1.parameters():
    param.requires_grad = False

for param in model.layer1.parameters():
    param.requires_grad = False

# for param in model.layer2.parameters():
#     param.requires_grad = False

# for param in model.layer3.parameters():
#     param.requires_grad = False

# for param in model.layer4.parameters():
#     param.requires_grad = False

# for param in model.avgpool.parameters():
#     param.requires_grad = False

# for param in model.fc.parameters():
#     param.requires_grad = False

# 定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(filter(lambda p: p.requires_grad, model.parameters()), 
                      lr=learning_rate, momentum=0.9)

# 训练模型
result = {
          "acu_train": [],
          "acu_test": [],
          "loss_train":[],
          "recall": []
          }
for epoch in range(num_epochs):
    for phase in ['train', 'val']:
        if phase == 'train':
            model.train()
        else:
            model.eval()

        running_loss = 0.0
        running_corrects = 0

        for inputs, labels in dataloaders[phase]:
            
#             print(phase,'epoch',":",epoch,'num_imputs',inputs.size())
#             tensor = inputs[0].to(torch.float32).cpu()
#             print(labels[0])
#             # 将张量转换为图像并显示
#             plt.imshow(tensor.permute(1, 2, 0))
#             plt.show()
            
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    loss.backward()
                    optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / dataset_sizes[phase]
        epoch_acc = running_corrects.double() / dataset_sizes[phase]
        
        if phase=='train':
            result["acu_train"].append('{:.4f}'.format(epoch_acc))
            result["loss_train"].append('{:.4f}'.format(epoch_loss))
        elif phase=='val':
            result["acu_test"].append('{:.4f}'.format(epoch_acc))
            recall = recall_score(labels.data.detach().cpu().numpy(), preds.detach().cpu().numpy(), average="macro")
            result["recall"].append(recall)

        print('epoch: {}, {} Loss: {:.4f} Acc: {:.4f}'.format(epoch, phase, epoch_loss, epoch_acc))
        with open('C:/Users/WHS/Desktop/Dual-ResNet18-SVM/result/result_file_ShuffleNet.txt', "a") as file:
            file.write('epoch: {}, {} Loss: {:.4f} Acc: {:.4f}\n'.format(epoch, phase, epoch_loss, epoch_acc))
# Out:
# epoch: 0, train Loss: 1.3884 Acc: 0.3101
# epoch: 0, val Loss: 1.3471 Acc: 0.3108
# epoch: 1, train Loss: 1.1025 Acc: 0.6415
# epoch: 1, val Loss: 1.1569 Acc: 0.5270
# epoch: 2, train Loss: 0.7943 Acc: 0.8023
# epoch: 2, val Loss: 0.8948 Acc: 0.7117
# epoch: 3, train Loss: 0.5052 Acc: 0.9264
# epoch: 3, val Loss: 0.7050 Acc: 0.7523
# epoch: 4, train Loss: 0.3349 Acc: 0.9554
# epoch: 4, val Loss: 0.5136 Acc: 0.8423
# epoch: 5, train Loss: 0.2407 Acc: 0.9748
# epoch: 5, val Loss: 0.3876 Acc: 0.9009
# epoch: 6, train Loss: 0.1828 Acc: 0.9690
# epoch: 6, val Loss: 0.3187 Acc: 0.9054
# epoch: 7, train Loss: 0.1430 Acc: 0.9767
# epoch: 7, val Loss: 0.2513 Acc: 0.9369
# epoch: 8, train Loss: 0.0959 Acc: 0.9981
# epoch: 8, val Loss: 0.2154 Acc: 0.9505
# epoch: 9, train Loss: 0.0894 Acc: 0.9942
# epoch: 9, val Loss: 0.2165 Acc: 0.9369
# epoch: 10, train Loss: 0.0683 Acc: 0.9981
# epoch: 10, val Loss: 0.2047 Acc: 0.9369
# epoch: 11, train Loss: 0.0561 Acc: 0.9942
# epoch: 11, val Loss: 0.1832 Acc: 0.9414
# epoch: 12, train Loss: 0.0382 Acc: 0.9981
# epoch: 12, val Loss: 0.1809 Acc: 0.9234
# epoch: 13, train Loss: 0.0370 Acc: 0.9961
# epoch: 13, val Loss: 0.1637 Acc: 0.9369
# epoch: 14, train Loss: 0.0344 Acc: 0.9942
# epoch: 14, val Loss: 0.1558 Acc: 0.9414
# epoch: 15, train Loss: 0.0353 Acc: 0.9961
# epoch: 15, val Loss: 0.1979 Acc: 0.9414
# epoch: 16, train Loss: 0.0752 Acc: 0.9787
# epoch: 16, val Loss: 0.2763 Acc: 0.8919
# epoch: 17, train Loss: 0.0529 Acc: 0.9922
# epoch: 17, val Loss: 0.1544 Acc: 0.9595
# epoch: 18, train Loss: 0.0249 Acc: 0.9981
# epoch: 18, val Loss: 0.1593 Acc: 0.9595
# epoch: 19, train Loss: 0.0282 Acc: 0.9942
# epoch: 19, val Loss: 0.1593 Acc: 0.9414
# epoch: 20, train Loss: 0.0276 Acc: 0.9961
# epoch: 20, val Loss: 0.1987 Acc: 0.9414
# epoch: 21, train Loss: 0.0380 Acc: 0.9884
# epoch: 21, val Loss: 0.1427 Acc: 0.9505
# epoch: 22, train Loss: 0.0269 Acc: 0.9981
# epoch: 22, val Loss: 0.1369 Acc: 0.9505
# epoch: 23, train Loss: 0.0325 Acc: 0.9981
# epoch: 23, val Loss: 0.1617 Acc: 0.9324
# epoch: 24, train Loss: 0.0230 Acc: 0.9981
# epoch: 24, val Loss: 0.2338 Acc: 0.9234
# epoch: 25, train Loss: 0.0537 Acc: 0.9884
# epoch: 25, val Loss: 0.2687 Acc: 0.9189
# epoch: 26, train Loss: 0.0350 Acc: 0.9942
# epoch: 26, val Loss: 0.2448 Acc: 0.9234
# epoch: 27, train Loss: 0.0453 Acc: 0.9884
# epoch: 27, val Loss: 0.1996 Acc: 0.9144
# epoch: 28, train Loss: 0.0481 Acc: 0.9903
# epoch: 28, val Loss: 0.1375 Acc: 0.9595
# epoch: 29, train Loss: 0.0284 Acc: 0.9942
# epoch: 29, val Loss: 0.1270 Acc: 0.9550
# epoch: 30, train Loss: 0.0177 Acc: 1.0000
# epoch: 30, val Loss: 0.1313 Acc: 0.9640
# epoch: 31, train Loss: 0.0155 Acc: 1.0000
# epoch: 31, val Loss: 0.1042 Acc: 0.9640
# epoch: 32, train Loss: 0.0082 Acc: 1.0000
# epoch: 32, val Loss: 0.0923 Acc: 0.9775
# epoch: 33, train Loss: 0.0098 Acc: 0.9981
# epoch: 33, val Loss: 0.1009 Acc: 0.9730
# epoch: 34, train Loss: 0.0114 Acc: 0.9981
# epoch: 34, val Loss: 0.1099 Acc: 0.9685
# epoch: 35, train Loss: 0.0401 Acc: 0.9884
# epoch: 35, val Loss: 0.1222 Acc: 0.9640
# epoch: 36, train Loss: 0.0223 Acc: 0.9961
# epoch: 36, val Loss: 0.1398 Acc: 0.9640
# epoch: 37, train Loss: 0.0208 Acc: 0.9961
# epoch: 37, val Loss: 0.2474 Acc: 0.9279
# epoch: 38, train Loss: 0.0186 Acc: 0.9981
# epoch: 38, val Loss: 0.2001 Acc: 0.9459
# epoch: 39, train Loss: 0.0129 Acc: 1.0000
# epoch: 39, val Loss: 0.1282 Acc: 0.9640
# epoch: 40, train Loss: 0.0106 Acc: 0.9981
# epoch: 40, val Loss: 0.0888 Acc: 0.9820
# epoch: 41, train Loss: 0.0097 Acc: 1.0000
# epoch: 41, val Loss: 0.1365 Acc: 0.9730
# epoch: 42, train Loss: 0.0206 Acc: 0.9942
# epoch: 42, val Loss: 0.1494 Acc: 0.9595
# epoch: 43, train Loss: 0.0182 Acc: 0.9961
# epoch: 43, val Loss: 0.1360 Acc: 0.9685
# epoch: 44, train Loss: 0.0047 Acc: 1.0000
# epoch: 44, val Loss: 0.1161 Acc: 0.9685
# epoch: 45, train Loss: 0.0122 Acc: 0.9981
# epoch: 45, val Loss: 0.1377 Acc: 0.9595
# epoch: 46, train Loss: 0.0123 Acc: 0.9961
# epoch: 46, val Loss: 0.1213 Acc: 0.9550
# epoch: 47, train Loss: 0.0069 Acc: 1.0000
# epoch: 47, val Loss: 0.2060 Acc: 0.9505
# epoch: 48, train Loss: 0.0097 Acc: 0.9981
# epoch: 48, val Loss: 0.2117 Acc: 0.9550
# epoch: 49, train Loss: 0.0126 Acc: 0.9981
# epoch: 49, val Loss: 0.1457 Acc: 0.9595
# epoch: 50, train Loss: 0.0097 Acc: 1.0000
# epoch: 50, val Loss: 0.1378 Acc: 0.9685
# epoch: 51, train Loss: 0.0061 Acc: 1.0000
# epoch: 51, val Loss: 0.1376 Acc: 0.9685
# epoch: 52, train Loss: 0.0067 Acc: 1.0000
# epoch: 52, val Loss: 0.1455 Acc: 0.9640
# epoch: 53, train Loss: 0.0159 Acc: 0.9981
# epoch: 53, val Loss: 0.1426 Acc: 0.9640
# epoch: 54, train Loss: 0.0190 Acc: 0.9981
# epoch: 54, val Loss: 0.2740 Acc: 0.9144
# epoch: 55, train Loss: 0.0291 Acc: 0.9942
# epoch: 55, val Loss: 0.1257 Acc: 0.9505
# epoch: 56, train Loss: 0.0103 Acc: 1.0000
# epoch: 56, val Loss: 0.0738 Acc: 0.9730
# epoch: 57, train Loss: 0.0106 Acc: 1.0000
# epoch: 57, val Loss: 0.0617 Acc: 0.9820
# epoch: 58, train Loss: 0.0090 Acc: 1.0000
# epoch: 58, val Loss: 0.0643 Acc: 0.9820
# epoch: 59, train Loss: 0.0141 Acc: 0.9981
# epoch: 59, val Loss: 0.0664 Acc: 0.9820
# epoch: 60, train Loss: 0.0100 Acc: 1.0000
# epoch: 60, val Loss: 0.1598 Acc: 0.9595
# epoch: 61, train Loss: 0.0128 Acc: 0.9961
# epoch: 61, val Loss: 0.1403 Acc: 0.9640
# epoch: 62, train Loss: 0.0187 Acc: 0.9942
# epoch: 62, val Loss: 0.1129 Acc: 0.9640
# epoch: 63, train Loss: 0.0276 Acc: 0.9884
# epoch: 63, val Loss: 0.2304 Acc: 0.9459
# epoch: 64, train Loss: 0.0455 Acc: 0.9884
# epoch: 64, val Loss: 0.1559 Acc: 0.9505
# epoch: 65, train Loss: 0.0160 Acc: 0.9961
# epoch: 65, val Loss: 0.1122 Acc: 0.9640
# epoch: 66, train Loss: 0.0145 Acc: 1.0000
# epoch: 66, val Loss: 0.1047 Acc: 0.9640
# epoch: 67, train Loss: 0.0197 Acc: 0.9942
# epoch: 67, val Loss: 0.0972 Acc: 0.9820
# epoch: 68, train Loss: 0.0072 Acc: 1.0000
# epoch: 68, val Loss: 0.0661 Acc: 0.9865
# epoch: 69, train Loss: 0.0123 Acc: 0.9981
# epoch: 69, val Loss: 0.0684 Acc: 0.9775
# epoch: 70, train Loss: 0.0080 Acc: 0.9981
# epoch: 70, val Loss: 0.0798 Acc: 0.9730
# epoch: 71, train Loss: 0.0104 Acc: 0.9981
# epoch: 71, val Loss: 0.0766 Acc: 0.9820
# epoch: 72, train Loss: 0.0059 Acc: 1.0000
# epoch: 72, val Loss: 0.0628 Acc: 0.9775
# epoch: 73, train Loss: 0.0123 Acc: 0.9942
# epoch: 73, val Loss: 0.0630 Acc: 0.9820
# epoch: 74, train Loss: 0.0176 Acc: 0.9961
# epoch: 74, val Loss: 0.1599 Acc: 0.9595
# epoch: 75, train Loss: 0.0123 Acc: 1.0000
# epoch: 75, val Loss: 0.1552 Acc: 0.9595
# epoch: 76, train Loss: 0.0096 Acc: 0.9981
# epoch: 76, val Loss: 0.1218 Acc: 0.9640
# epoch: 77, train Loss: 0.0071 Acc: 1.0000
# epoch: 77, val Loss: 0.0736 Acc: 0.9775
# epoch: 78, train Loss: 0.0141 Acc: 0.9981
# epoch: 78, val Loss: 0.0512 Acc: 0.9820
# epoch: 79, train Loss: 0.0183 Acc: 0.9981
# epoch: 79, val Loss: 0.2150 Acc: 0.9595
# epoch: 80, train Loss: 0.0375 Acc: 0.9884
# epoch: 80, val Loss: 0.0675 Acc: 0.9775
# epoch: 81, train Loss: 0.0169 Acc: 0.9961
# epoch: 81, val Loss: 0.0525 Acc: 0.9865
# epoch: 82, train Loss: 0.0109 Acc: 0.9981
# epoch: 82, val Loss: 0.0745 Acc: 0.9865
# epoch: 83, train Loss: 0.0121 Acc: 0.9981
# epoch: 83, val Loss: 0.0814 Acc: 0.9775
# epoch: 84, train Loss: 0.0229 Acc: 0.9903
# epoch: 84, val Loss: 0.0875 Acc: 0.9730
# epoch: 85, train Loss: 0.0132 Acc: 0.9981
# epoch: 85, val Loss: 0.0977 Acc: 0.9685
# epoch: 86, train Loss: 0.0184 Acc: 0.9961
# epoch: 86, val Loss: 0.0516 Acc: 0.9820
# epoch: 87, train Loss: 0.0077 Acc: 0.9981
# epoch: 87, val Loss: 0.0486 Acc: 0.9820
# epoch: 88, train Loss: 0.0056 Acc: 1.0000
# epoch: 88, val Loss: 0.0421 Acc: 0.9865
# epoch: 89, train Loss: 0.0030 Acc: 1.0000
# epoch: 89, val Loss: 0.0402 Acc: 0.9865
# epoch: 90, train Loss: 0.0067 Acc: 0.9981
# epoch: 90, val Loss: 0.0423 Acc: 0.9865
# epoch: 91, train Loss: 0.0074 Acc: 0.9981
# epoch: 91, val Loss: 0.0601 Acc: 0.9820
# epoch: 92, train Loss: 0.0115 Acc: 0.9981
# epoch: 92, val Loss: 0.0777 Acc: 0.9775
# epoch: 93, train Loss: 0.0209 Acc: 0.9961
# epoch: 93, val Loss: 0.0661 Acc: 0.9730
# epoch: 94, train Loss: 0.0190 Acc: 0.9961
# epoch: 94, val Loss: 0.0666 Acc: 0.9775
# epoch: 95, train Loss: 0.0106 Acc: 0.9981
# epoch: 95, val Loss: 0.0526 Acc: 0.9775
# epoch: 96, train Loss: 0.0574 Acc: 0.9826
# epoch: 96, val Loss: 0.1717 Acc: 0.9550
# epoch: 97, train Loss: 0.0263 Acc: 0.9903
# epoch: 97, val Loss: 0.0440 Acc: 0.9820
# epoch: 98, train Loss: 0.0238 Acc: 0.9942
# epoch: 98, val Loss: 0.0318 Acc: 0.9910
# epoch: 99, train Loss: 0.0137 Acc: 0.9961
# epoch: 99, val Loss: 0.0906 Acc: 0.9685

# %%
# 记录结束时间
end_time = time.time()

# 计算算法运行时间
execution_time = end_time - start_time
print(execution_time)
# Out:
# 662.5615880489349

# %%
torch.save(model.state_dict(), 'ResNet50.pth')

# %%
import os
import time
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, models, transforms
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from torch.utils.data import ConcatDataset
from sklearn.model_selection import train_test_split
start_time = time.time()
data_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
# 加载数据集
data_dir = 'C:/Users/WHS/Desktop/SVM-Image-Classification-master/images3'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms) for x in ['train', 'val']}
test_loader = torch.utils.data.DataLoader(image_datasets['val'], batch_size=64, shuffle=True, num_workers=4)

# 加载预训练模型
model = models.resnet50()
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 4)
device = torch.device('cuda:0')
model = model.to(device)

# 加载之前保存的模型参数
model.load_state_dict(torch.load('ResNet50.pth'))

for inputs, labels in test_loader:    
    inputs = inputs.to(device)
    labels = labels.to(device)
    outputs = model(inputs)
    _, preds = torch.max(outputs, 1)
    print(labels,preds)
    break
# 记录结束时间
end_time = time.time()

# 计算算法运行时间
execution_time = end_time - start_time
print(execution_time/len(labels))
# Out:
# tensor([1, 1, 0, 2, 3, 1, 2, 0, 0, 2, 0, 3, 3, 3, 2, 3, 2, 1, 3, 2, 3, 0, 3, 2,
#         1, 2, 2, 1, 0, 1, 3, 2, 2, 0, 0, 1, 2, 3, 3, 2, 3, 1, 0, 1, 3, 1, 0, 3,
#         3, 1, 3, 2, 0, 3, 0, 2, 1, 0, 2, 1, 1, 0, 0, 0], device='cuda:0') tensor([1, 1, 0, 2, 0, 1, 2, 0, 0, 2, 0, 3, 3, 3, 2, 3, 2, 1, 2, 2, 3, 0, 3, 2,
#         1, 2, 2, 3, 0, 1, 3, 2, 2, 0, 0, 1, 2, 3, 3, 2, 3, 1, 0, 1, 3, 1, 0, 3,
#         3, 1, 3, 2, 0, 3, 2, 2, 1, 0, 2, 1, 1, 0, 0, 0], device='cuda:0')
# 0.08420650660991669

# %%
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


"""Use this method directly - """
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    matplotlib.rcParams['font.size'] = 18
    matplotlib.rcParams['font.family'] = 'Times New Roman'
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    fig = plt.gcf()
    fig.set_size_inches(5, 4)
    fig.subplots_adjust(left=0.2, bottom=0.2)
    fig.savefig('ResNet50_con.png', dpi=300)
    plt.tight_layout()

# %%
labels = labels.cpu()
preds = preds.cpu()
cnf_matrix = confusion_matrix(labels.data, preds)
print(cnf_matrix)
# Out:
# [[15  0  1  0]
#  [ 0 14  0  1]
#  [ 0  0 16  0]
#  [ 1  0  1 15]]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(labels.data, preds)
plt.figure()
plot_confusion_matrix(cnf_matrix, ['hole','norm','float','broken'],normalize=True,title='Accuracy={:.2f}%'.format(accuracy*100),cmap=plt.cm.Blues)
# Out:
# Normalized confusion matrix
# [[0.9375     0.         0.0625     0.        ]
#  [0.         0.93333333 0.         0.06666667]
#  [0.         0.         1.         0.        ]
#  [0.05882353 0.         0.05882353 0.88235294]]
# <ipython-input-2-9d29c1685bda>:46: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
