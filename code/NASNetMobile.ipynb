# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, recall_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.optimizers import SGD
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# 记录开始时间
start_time = time.time()

# 定义超参数
batch_size = 64
learning_rate = 0.001
num_epochs = 100

data_transforms = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.3)

# 加载数据集
data_dir = 'C:/Users/WHS/Desktop/SVM-Image-Classification-master/images4'

train_generator = data_transforms.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

test_generator = data_transforms.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation')
# 将训练集转换为NumPy数组并打乱顺序
train_data = []
train_labels = []
for i in range(len(train_generator)):
    batch_data, batch_labels = train_generator[i]
    train_data.append(batch_data)
    train_labels.append(batch_labels)
train_data = np.concatenate(train_data)
train_labels = np.concatenate(train_labels)
train_data, train_labels = shuffle(train_data, train_labels)

# 将测试集转换为NumPy数组并打乱顺序
test_data = []
test_labels = []
for i in range(len(test_generator)):
    batch_data, batch_labels = test_generator[i]
    test_data.append(batch_data)
    test_labels.append(batch_labels)
test_data = np.concatenate(test_data)
test_labels = np.concatenate(test_labels)
test_data, test_labels = shuffle(test_data, test_labels)
# Out:
# Found 518 images belonging to 4 classes.
# Found 220 images belonging to 4 classes.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# 加载预训练的NASNetMobile模型
base_model = keras.applications.NASNetMobile(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# 冻结预训练模型的权重
base_model.trainable = False

# 添加自定义的分类层
model = keras.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(4, activation='softmax')
])

# 编译模型
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 训练模型
history = model.fit(train_data, train_labels, epochs=num_epochs, validation_data=(test_data, test_labels))

# 输出损失率和准确率到txt文件
with open('C:/Users/WHS/Desktop/Dual-ResNet18-SVM/result_file_NASNetMobile.txt', 'w') as file:
    file.write('Epoch\tTrain Loss\tTrain Accuracy\tTest Loss\tTest Accuracy\n')
    for epoch in range(num_epochs):
        file.write('{}\t{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}\n'.format(
            epoch, history.history['loss'][epoch], history.history['accuracy'][epoch],
            history.history['val_loss'][epoch], history.history['val_accuracy'][epoch])
        )
# Out:
# Epoch 1/100
# 17/17 [==============================] - 15s 888ms/step - loss: 1.2738 - accuracy: 0.3938 - val_loss: 1.2009 - val_accuracy: 0.4364
# Epoch 2/100
# 17/17 [==============================] - 12s 686ms/step - loss: 0.9598 - accuracy: 0.6293 - val_loss: 1.0664 - val_accuracy: 0.5636
# Epoch 3/100
# 17/17 [==============================] - 12s 679ms/step - loss: 0.8029 - accuracy: 0.7162 - val_loss: 0.9432 - val_accuracy: 0.6318
# Epoch 4/100
# 17/17 [==============================] - 12s 684ms/step - loss: 0.6969 - accuracy: 0.7896 - val_loss: 0.8952 - val_accuracy: 0.6136
# Epoch 5/100
# 17/17 [==============================] - 12s 682ms/step - loss: 0.6209 - accuracy: 0.8205 - val_loss: 0.8430 - val_accuracy: 0.6500
# Epoch 6/100
# 17/17 [==============================] - 12s 684ms/step - loss: 0.5606 - accuracy: 0.8514 - val_loss: 0.8096 - val_accuracy: 0.6591
# Epoch 7/100
# 17/17 [==============================] - 12s 691ms/step - loss: 0.5156 - accuracy: 0.8571 - val_loss: 0.7692 - val_accuracy: 0.6682
# Epoch 8/100
# 17/17 [==============================] - 12s 693ms/step - loss: 0.4797 - accuracy: 0.8784 - val_loss: 0.7498 - val_accuracy: 0.6773
# Epoch 9/100
# 17/17 [==============================] - 12s 699ms/step - loss: 0.4507 - accuracy: 0.8668 - val_loss: 0.7481 - val_accuracy: 0.6682
# Epoch 10/100
# 17/17 [==============================] - 12s 693ms/step - loss: 0.4248 - accuracy: 0.8861 - val_loss: 0.7187 - val_accuracy: 0.6773
# Epoch 11/100
# 17/17 [==============================] - 12s 684ms/step - loss: 0.3969 - accuracy: 0.9035 - val_loss: 0.7094 - val_accuracy: 0.6727
# Epoch 12/100
# 17/17 [==============================] - 12s 702ms/step - loss: 0.3810 - accuracy: 0.8958 - val_loss: 0.6960 - val_accuracy: 0.6636
# Epoch 13/100
# 17/17 [==============================] - 12s 694ms/step - loss: 0.3601 - accuracy: 0.8977 - val_loss: 0.6892 - val_accuracy: 0.6818
# Epoch 14/100
# 17/17 [==============================] - 12s 693ms/step - loss: 0.3459 - accuracy: 0.9035 - val_loss: 0.6677 - val_accuracy: 0.6909
# Epoch 15/100
# 17/17 [==============================] - 12s 693ms/step - loss: 0.3276 - accuracy: 0.9170 - val_loss: 0.6722 - val_accuracy: 0.6909
# Epoch 16/100
# 17/17 [==============================] - 12s 692ms/step - loss: 0.3162 - accuracy: 0.9208 - val_loss: 0.6607 - val_accuracy: 0.6818
# Epoch 17/100
# 17/17 [==============================] - 12s 695ms/step - loss: 0.3128 - accuracy: 0.9189 - val_loss: 0.6544 - val_accuracy: 0.6909
# Epoch 18/100
# 17/17 [==============================] - 12s 688ms/step - loss: 0.2922 - accuracy: 0.9266 - val_loss: 0.6435 - val_accuracy: 0.7000
# Epoch 19/100
# 17/17 [==============================] - 12s 683ms/step - loss: 0.2835 - accuracy: 0.9170 - val_loss: 0.6368 - val_accuracy: 0.7045
# Epoch 20/100
# 17/17 [==============================] - 12s 679ms/step - loss: 0.2762 - accuracy: 0.9305 - val_loss: 0.6256 - val_accuracy: 0.7000
# Epoch 21/100
# 17/17 [==============================] - 12s 681ms/step - loss: 0.2695 - accuracy: 0.9382 - val_loss: 0.6200 - val_accuracy: 0.7227
# Epoch 22/100
# 17/17 [==============================] - 12s 682ms/step - loss: 0.2564 - accuracy: 0.9305 - val_loss: 0.6184 - val_accuracy: 0.7273
# Epoch 23/100
# 17/17 [==============================] - 12s 681ms/step - loss: 0.2526 - accuracy: 0.9363 - val_loss: 0.6178 - val_accuracy: 0.7091
# Epoch 24/100
# 17/17 [==============================] - 12s 681ms/step - loss: 0.2454 - accuracy: 0.9421 - val_loss: 0.6289 - val_accuracy: 0.7000
# Epoch 25/100
# 17/17 [==============================] - 12s 678ms/step - loss: 0.2360 - accuracy: 0.9421 - val_loss: 0.6040 - val_accuracy: 0.7182
# Epoch 26/100
# 17/17 [==============================] - 12s 689ms/step - loss: 0.2300 - accuracy: 0.9402 - val_loss: 0.5879 - val_accuracy: 0.7318
# Epoch 27/100
# 17/17 [==============================] - 12s 694ms/step - loss: 0.2234 - accuracy: 0.9421 - val_loss: 0.5957 - val_accuracy: 0.7455
# Epoch 28/100
# 17/17 [==============================] - 12s 700ms/step - loss: 0.2154 - accuracy: 0.9440 - val_loss: 0.5844 - val_accuracy: 0.7545
# Epoch 29/100
# 17/17 [==============================] - 12s 683ms/step - loss: 0.2184 - accuracy: 0.9382 - val_loss: 0.6136 - val_accuracy: 0.7136
# Epoch 30/100
# 17/17 [==============================] - 12s 691ms/step - loss: 0.2077 - accuracy: 0.9479 - val_loss: 0.5804 - val_accuracy: 0.7500
# Epoch 31/100
# 17/17 [==============================] - 12s 696ms/step - loss: 0.2001 - accuracy: 0.9479 - val_loss: 0.5913 - val_accuracy: 0.7455
# Epoch 32/100
# 17/17 [==============================] - 12s 682ms/step - loss: 0.1939 - accuracy: 0.9556 - val_loss: 0.5749 - val_accuracy: 0.7545
# Epoch 33/100
# 17/17 [==============================] - 12s 682ms/step - loss: 0.1891 - accuracy: 0.9556 - val_loss: 0.5849 - val_accuracy: 0.7455
# Epoch 34/100
# 17/17 [==============================] - 12s 713ms/step - loss: 0.1874 - accuracy: 0.9537 - val_loss: 0.5625 - val_accuracy: 0.7545
# Epoch 35/100
# 17/17 [==============================] - 12s 714ms/step - loss: 0.1818 - accuracy: 0.9633 - val_loss: 0.5692 - val_accuracy: 0.7636
# Epoch 36/100
# 17/17 [==============================] - 12s 695ms/step - loss: 0.1768 - accuracy: 0.9653 - val_loss: 0.5679 - val_accuracy: 0.7591
# Epoch 37/100
# 17/17 [==============================] - 12s 693ms/step - loss: 0.1742 - accuracy: 0.9595 - val_loss: 0.5585 - val_accuracy: 0.7545
# Epoch 38/100
# 17/17 [==============================] - 12s 681ms/step - loss: 0.1709 - accuracy: 0.9633 - val_loss: 0.5693 - val_accuracy: 0.7545
# Epoch 39/100
# 17/17 [==============================] - 12s 680ms/step - loss: 0.1670 - accuracy: 0.9672 - val_loss: 0.5529 - val_accuracy: 0.7545
# Epoch 40/100
# 17/17 [==============================] - 12s 681ms/step - loss: 0.1625 - accuracy: 0.9710 - val_loss: 0.5575 - val_accuracy: 0.7636
# Epoch 41/100
# 17/17 [==============================] - 12s 677ms/step - loss: 0.1593 - accuracy: 0.9672 - val_loss: 0.5644 - val_accuracy: 0.7545
# Epoch 42/100
# 17/17 [==============================] - 12s 677ms/step - loss: 0.1557 - accuracy: 0.9691 - val_loss: 0.5558 - val_accuracy: 0.7591
# Epoch 43/100
# 17/17 [==============================] - 12s 680ms/step - loss: 0.1530 - accuracy: 0.9653 - val_loss: 0.5583 - val_accuracy: 0.7636
# Epoch 44/100
# 17/17 [==============================] - 11s 675ms/step - loss: 0.1491 - accuracy: 0.9691 - val_loss: 0.5528 - val_accuracy: 0.7591
# Epoch 45/100
# 17/17 [==============================] - 12s 677ms/step - loss: 0.1473 - accuracy: 0.9749 - val_loss: 0.5495 - val_accuracy: 0.7636
# Epoch 46/100
# 17/17 [==============================] - 12s 680ms/step - loss: 0.1476 - accuracy: 0.9710 - val_loss: 0.5440 - val_accuracy: 0.7864
# Epoch 47/100
# 17/17 [==============================] - 12s 679ms/step - loss: 0.1425 - accuracy: 0.9691 - val_loss: 0.5453 - val_accuracy: 0.7727
# Epoch 48/100
# 17/17 [==============================] - 12s 680ms/step - loss: 0.1407 - accuracy: 0.9749 - val_loss: 0.5433 - val_accuracy: 0.7682
# Epoch 49/100
# 17/17 [==============================] - 11s 676ms/step - loss: 0.1373 - accuracy: 0.9730 - val_loss: 0.5427 - val_accuracy: 0.7727
# Epoch 50/100
# 17/17 [==============================] - 12s 691ms/step - loss: 0.1357 - accuracy: 0.9691 - val_loss: 0.5340 - val_accuracy: 0.7864
# Epoch 51/100
# 17/17 [==============================] - 12s 691ms/step - loss: 0.1362 - accuracy: 0.9749 - val_loss: 0.5694 - val_accuracy: 0.7545
# Epoch 52/100
# 17/17 [==============================] - 12s 694ms/step - loss: 0.1329 - accuracy: 0.9768 - val_loss: 0.5294 - val_accuracy: 0.7818
# Epoch 53/100
# 17/17 [==============================] - 12s 698ms/step - loss: 0.1256 - accuracy: 0.9788 - val_loss: 0.5449 - val_accuracy: 0.7636
# Epoch 54/100
# 17/17 [==============================] - 12s 678ms/step - loss: 0.1267 - accuracy: 0.9788 - val_loss: 0.5449 - val_accuracy: 0.7591
# Epoch 55/100
# 17/17 [==============================] - 12s 689ms/step - loss: 0.1217 - accuracy: 0.9788 - val_loss: 0.5284 - val_accuracy: 0.7864
# Epoch 56/100
# 17/17 [==============================] - 12s 680ms/step - loss: 0.1220 - accuracy: 0.9788 - val_loss: 0.5384 - val_accuracy: 0.7591
# Epoch 57/100
# 17/17 [==============================] - 12s 682ms/step - loss: 0.1250 - accuracy: 0.9807 - val_loss: 0.5322 - val_accuracy: 0.7727
# Epoch 58/100
# 17/17 [==============================] - 12s 696ms/step - loss: 0.1182 - accuracy: 0.9826 - val_loss: 0.5462 - val_accuracy: 0.7636
# Epoch 59/100
# 17/17 [==============================] - 12s 679ms/step - loss: 0.1210 - accuracy: 0.9807 - val_loss: 0.5333 - val_accuracy: 0.7864
# Epoch 60/100
# 17/17 [==============================] - 12s 679ms/step - loss: 0.1135 - accuracy: 0.9865 - val_loss: 0.5396 - val_accuracy: 0.7591
# Epoch 61/100
# 17/17 [==============================] - 12s 685ms/step - loss: 0.1119 - accuracy: 0.9807 - val_loss: 0.5287 - val_accuracy: 0.7727
# Epoch 62/100
# 17/17 [==============================] - 12s 680ms/step - loss: 0.1088 - accuracy: 0.9788 - val_loss: 0.5247 - val_accuracy: 0.7909
# Epoch 63/100
# 17/17 [==============================] - 12s 685ms/step - loss: 0.1067 - accuracy: 0.9846 - val_loss: 0.5256 - val_accuracy: 0.7818
# Epoch 64/100
# 17/17 [==============================] - 12s 682ms/step - loss: 0.1042 - accuracy: 0.9884 - val_loss: 0.5171 - val_accuracy: 0.7818
# Epoch 65/100
# 17/17 [==============================] - 12s 684ms/step - loss: 0.1023 - accuracy: 0.9846 - val_loss: 0.5235 - val_accuracy: 0.7727
# Epoch 66/100
# 17/17 [==============================] - 12s 687ms/step - loss: 0.1019 - accuracy: 0.9923 - val_loss: 0.5334 - val_accuracy: 0.7864
# Epoch 67/100
# 17/17 [==============================] - 12s 686ms/step - loss: 0.1006 - accuracy: 0.9884 - val_loss: 0.5235 - val_accuracy: 0.7773
# Epoch 68/100
# 17/17 [==============================] - 12s 684ms/step - loss: 0.1001 - accuracy: 0.9846 - val_loss: 0.5245 - val_accuracy: 0.7682
# Epoch 69/100
# 17/17 [==============================] - 12s 683ms/step - loss: 0.1039 - accuracy: 0.9826 - val_loss: 0.5039 - val_accuracy: 0.8045
# Epoch 70/100
# 17/17 [==============================] - 12s 678ms/step - loss: 0.1013 - accuracy: 0.9865 - val_loss: 0.5281 - val_accuracy: 0.7682
# Epoch 71/100
# 17/17 [==============================] - 12s 683ms/step - loss: 0.0962 - accuracy: 0.9865 - val_loss: 0.5242 - val_accuracy: 0.7773
# Epoch 72/100
# 17/17 [==============================] - 12s 682ms/step - loss: 0.0928 - accuracy: 0.9865 - val_loss: 0.5142 - val_accuracy: 0.8000
# Epoch 73/100
# 17/17 [==============================] - 12s 692ms/step - loss: 0.0930 - accuracy: 0.9884 - val_loss: 0.5224 - val_accuracy: 0.7773
# Epoch 74/100
# 17/17 [==============================] - 12s 692ms/step - loss: 0.0892 - accuracy: 0.9942 - val_loss: 0.5136 - val_accuracy: 0.7773
# Epoch 75/100
# 17/17 [==============================] - 12s 698ms/step - loss: 0.0889 - accuracy: 0.9903 - val_loss: 0.5056 - val_accuracy: 0.7909
# Epoch 76/100
# 17/17 [==============================] - 12s 696ms/step - loss: 0.0871 - accuracy: 0.9884 - val_loss: 0.5099 - val_accuracy: 0.7864
# Epoch 77/100
# 17/17 [==============================] - 12s 694ms/step - loss: 0.0855 - accuracy: 0.9942 - val_loss: 0.5160 - val_accuracy: 0.7909
# Epoch 78/100
# 17/17 [==============================] - 12s 694ms/step - loss: 0.0912 - accuracy: 0.9826 - val_loss: 0.5366 - val_accuracy: 0.7636
# Epoch 79/100
# 17/17 [==============================] - 12s 683ms/step - loss: 0.0881 - accuracy: 0.9884 - val_loss: 0.5035 - val_accuracy: 0.8091
# Epoch 80/100
# 17/17 [==============================] - 12s 679ms/step - loss: 0.0835 - accuracy: 0.9942 - val_loss: 0.5235 - val_accuracy: 0.7636
# Epoch 81/100
# 17/17 [==============================] - 12s 681ms/step - loss: 0.0833 - accuracy: 0.9884 - val_loss: 0.5212 - val_accuracy: 0.7682
# Epoch 82/100
# 17/17 [==============================] - 12s 678ms/step - loss: 0.0799 - accuracy: 0.9942 - val_loss: 0.5029 - val_accuracy: 0.7955
# Epoch 83/100
# 17/17 [==============================] - 12s 689ms/step - loss: 0.0792 - accuracy: 0.9942 - val_loss: 0.5016 - val_accuracy: 0.7909
# Epoch 84/100
# 17/17 [==============================] - 12s 681ms/step - loss: 0.0774 - accuracy: 0.9923 - val_loss: 0.5129 - val_accuracy: 0.7818
# Epoch 85/100
# 17/17 [==============================] - 12s 682ms/step - loss: 0.0790 - accuracy: 0.9942 - val_loss: 0.5016 - val_accuracy: 0.8136
# Epoch 86/100
# 17/17 [==============================] - 12s 686ms/step - loss: 0.0761 - accuracy: 0.9961 - val_loss: 0.4871 - val_accuracy: 0.8136
# Epoch 87/100
# 17/17 [==============================] - 12s 689ms/step - loss: 0.0749 - accuracy: 0.9961 - val_loss: 0.5062 - val_accuracy: 0.8000
# Epoch 88/100
# 17/17 [==============================] - 12s 681ms/step - loss: 0.0732 - accuracy: 0.9942 - val_loss: 0.5034 - val_accuracy: 0.8182
# Epoch 89/100
# 17/17 [==============================] - 12s 681ms/step - loss: 0.0755 - accuracy: 0.9903 - val_loss: 0.5098 - val_accuracy: 0.7955
# Epoch 90/100
# 17/17 [==============================] - 12s 680ms/step - loss: 0.0711 - accuracy: 0.9942 - val_loss: 0.5009 - val_accuracy: 0.8136
# Epoch 91/100
# 17/17 [==============================] - 12s 682ms/step - loss: 0.0706 - accuracy: 0.9942 - val_loss: 0.5087 - val_accuracy: 0.8000
# Epoch 92/100
# 17/17 [==============================] - 12s 693ms/step - loss: 0.0693 - accuracy: 0.9981 - val_loss: 0.5089 - val_accuracy: 0.8000
# Epoch 93/100
# 17/17 [==============================] - 12s 696ms/step - loss: 0.0694 - accuracy: 0.9961 - val_loss: 0.4990 - val_accuracy: 0.8136
# Epoch 94/100
# 17/17 [==============================] - 12s 679ms/step - loss: 0.0708 - accuracy: 0.9923 - val_loss: 0.5054 - val_accuracy: 0.7909
# Epoch 95/100
# 17/17 [==============================] - 12s 698ms/step - loss: 0.0675 - accuracy: 0.9942 - val_loss: 0.5078 - val_accuracy: 0.8045
# Epoch 96/100
# 17/17 [==============================] - 12s 699ms/step - loss: 0.0664 - accuracy: 0.9942 - val_loss: 0.5021 - val_accuracy: 0.8000
# Epoch 97/100
# 17/17 [==============================] - 12s 694ms/step - loss: 0.0652 - accuracy: 0.9961 - val_loss: 0.4995 - val_accuracy: 0.8182
# Epoch 98/100
# 17/17 [==============================] - 12s 698ms/step - loss: 0.0657 - accuracy: 0.9942 - val_loss: 0.5086 - val_accuracy: 0.8091
# Epoch 99/100
# 17/17 [==============================] - 12s 694ms/step - loss: 0.0635 - accuracy: 0.9981 - val_loss: 0.5034 - val_accuracy: 0.8182
# Epoch 100/100
# 17/17 [==============================] - 12s 696ms/step - loss: 0.0627 - accuracy: 0.9961 - val_loss: 0.4976 - val_accuracy: 0.8136

# %%
# 记录结束时间
end_time = time.time()

# 计算算法运行时间
execution_time = end_time - start_time
print(execution_time)
# Out:
# 1259.3571257591248

# %%
model.save_weights('NASNetMobile_weights.h5')

# %%
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


base_model = keras.applications.NASNetMobile(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# 冻结预训练模型的权重
base_model.trainable = False

# 添加自定义的分类层
model = keras.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(4, activation='softmax')
])
model.load_weights('NASNetMobile_weights.h5')

start_time = time.time()
# 对测试集进行预测
y_pred = model.predict(test_data)
y_pred = np.argmax(y_pred, axis=1)  # 将预测的概率转换为类别标签
test_labels = np.argmax(test_labels, axis=1)
print(y_pred,test_labels)
# 记录结束时间
end_time = time.time()

# 计算算法运行时间
execution_time = end_time - start_time
print(execution_time/len(test_labels))
# Out:
# [2 1 3 0 0 3 3 3 1 0 2 1 3 2 1 3 3 2 1 3 3 2 1 0 1 1 2 3 0 0 2 1 1 0 1 1 1
#  3 1 0 1 3 3 2 2 3 1 3 3 2 1 3 3 0 1 1 0 0 1 0 0 2 0 2 1 1 0 3 1 2 3 3 2 1
#  0 0 0 1 1 1 2 0 1 0 3 2 0 0 1 1 1 1 3 0 3 1 2 2 1 3 0 1 3 1 1 2 1 3 0 0 0
#  3 0 2 0 2 2 2 1 0 0 0 3 1 3 0 3 0 1 1 1 3 2 3 0 3 0 2 2 1 0 2 0 1 1 3 2 3
#  0 0 2 1 2 3 0 2 1 0 1 2 3 0 3 0 1 1 2 1 1 2 2 3 2 3 0 1 3 3 1 2 0 3 3 1 1
#  3 3 2 3 1 2 0 0 1 0 3 2 2 0 3 0 3 2 3 3 1 1 2 3 1 3 2 1 3 0 2 3 3 3 1] [2 1 0 0 3 3 3 0 1 0 2 0 2 2 1 0 3 2 1 3 3 2 2 1 0 1 2 1 0 0 2 1 0 1 3 0 1
#  3 2 0 1 2 3 2 2 0 1 3 3 2 1 3 3 3 3 0 1 0 1 0 0 2 3 2 3 3 1 3 1 2 0 0 2 1
#  3 3 0 1 1 1 2 0 1 0 3 2 3 0 1 1 0 1 3 0 3 1 2 2 1 3 0 1 3 1 1 2 1 0 2 0 3
#  3 1 2 0 2 2 2 1 2 0 0 1 1 3 0 3 0 1 2 0 3 2 0 0 3 0 2 2 1 0 2 0 1 1 3 2 3
#  0 0 2 1 2 0 0 2 1 0 1 2 3 1 3 0 1 1 2 2 1 2 2 3 2 3 0 1 3 3 1 2 0 0 3 1 1
#  3 3 2 1 1 2 0 3 1 0 0 2 2 0 3 3 0 2 3 3 1 0 2 3 1 3 2 0 2 0 2 3 3 3 1]
# 0.032552760297601874

# %%
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


"""Use this method directly - """
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    matplotlib.rcParams['font.size'] = 17
    matplotlib.rcParams['font.family'] = 'Times New Roman'
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    fig = plt.gcf()
    fig.set_size_inches(5, 4)
    fig.subplots_adjust(left=0.2, bottom=0.2)
    fig.savefig('NASNetMobile_con.png', dpi=300)
    plt.tight_layout()

# %%
cnf_matrix = confusion_matrix(y_pred,test_labels)
print(cnf_matrix)
# Out:
# [[35  6  2  9]
#  [ 9 47  4  4]
#  [ 0  0 45  0]
#  [12  3  3 41]]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_pred,test_labels)
plt.figure()
plot_confusion_matrix(cnf_matrix, ['hole','norm','float','broken'],normalize=True,title='Accuracy={:.2f}%'.format(accuracy*100),cmap=plt.cm.Blues)
# Out:
# Normalized confusion matrix
# [[0.67307692 0.11538462 0.03846154 0.17307692]
#  [0.140625   0.734375   0.0625     0.0625    ]
#  [0.         0.         1.         0.        ]
#  [0.20338983 0.05084746 0.05084746 0.69491525]]
