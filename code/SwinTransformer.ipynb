# %% [markdown]
# # Swin Transformer-Tiny
#
# Unified four-class training and evaluation.

# %%
from ml_experiments import TorchConfig, run_torch_experiment

# %%
config = TorchConfig(
    model_name='swin_t',
    checkpoint='SwinTransformer.pth',
    epochs=100,
    freeze_backbone=True,
)
result = run_torch_experiment(config)
# Out:
# Downloading: "https://download.pytorch.org/models/swin_t-704ceda3.pth" to C:\Users\WHS/.cache\torch\hub\checkpoints\swin_t-704ceda3.pth
#   0%|          | 0.00/108M [00:00<?, ?B/s]
# swin_t: epoch 1/100 | train_acc=0.306 | val_acc=0.369
# swin_t: epoch 2/100 | train_acc=0.393 | val_acc=0.590
# swin_t: epoch 3/100 | train_acc=0.481 | val_acc=0.590
# swin_t: epoch 4/100 | train_acc=0.568 | val_acc=0.689
# swin_t: epoch 5/100 | train_acc=0.671 | val_acc=0.784
# swin_t: epoch 6/100 | train_acc=0.661 | val_acc=0.815
# swin_t: epoch 7/100 | train_acc=0.696 | val_acc=0.761
# swin_t: epoch 8/100 | train_acc=0.698 | val_acc=0.784
# swin_t: epoch 9/100 | train_acc=0.688 | val_acc=0.838
# swin_t: epoch 10/100 | train_acc=0.713 | val_acc=0.820
# swin_t: epoch 11/100 | train_acc=0.725 | val_acc=0.784
# swin_t: epoch 12/100 | train_acc=0.711 | val_acc=0.838
# swin_t: epoch 13/100 | train_acc=0.740 | val_acc=0.842
# swin_t: epoch 14/100 | train_acc=0.729 | val_acc=0.847
# swin_t: epoch 15/100 | train_acc=0.750 | val_acc=0.865
# swin_t: epoch 16/100 | train_acc=0.754 | val_acc=0.833
# swin_t: epoch 17/100 | train_acc=0.754 | val_acc=0.860
# swin_t: epoch 18/100 | train_acc=0.758 | val_acc=0.869
# swin_t: epoch 19/100 | train_acc=0.758 | val_acc=0.874
# swin_t: epoch 20/100 | train_acc=0.769 | val_acc=0.883
# swin_t: epoch 21/100 | train_acc=0.771 | val_acc=0.874
# swin_t: epoch 22/100 | train_acc=0.777 | val_acc=0.892
# swin_t: epoch 23/100 | train_acc=0.771 | val_acc=0.896
# swin_t: epoch 24/100 | train_acc=0.764 | val_acc=0.887
# swin_t: epoch 25/100 | train_acc=0.793 | val_acc=0.878
# swin_t: epoch 26/100 | train_acc=0.800 | val_acc=0.883
# swin_t: epoch 27/100 | train_acc=0.783 | val_acc=0.878
# swin_t: epoch 28/100 | train_acc=0.787 | val_acc=0.887
# swin_t: epoch 29/100 | train_acc=0.810 | val_acc=0.896
# swin_t: epoch 30/100 | train_acc=0.806 | val_acc=0.887
# swin_t: epoch 31/100 | train_acc=0.789 | val_acc=0.896
# swin_t: epoch 32/100 | train_acc=0.793 | val_acc=0.851
# swin_t: epoch 33/100 | train_acc=0.787 | val_acc=0.896
# swin_t: epoch 34/100 | train_acc=0.789 | val_acc=0.887
# swin_t: epoch 35/100 | train_acc=0.771 | val_acc=0.878
# swin_t: epoch 36/100 | train_acc=0.802 | val_acc=0.896
# swin_t: epoch 37/100 | train_acc=0.829 | val_acc=0.887
# swin_t: epoch 38/100 | train_acc=0.798 | val_acc=0.869
# swin_t: epoch 39/100 | train_acc=0.818 | val_acc=0.883
# swin_t: epoch 40/100 | train_acc=0.797 | val_acc=0.901
# swin_t: epoch 41/100 | train_acc=0.785 | val_acc=0.901
# swin_t: epoch 42/100 | train_acc=0.804 | val_acc=0.887
# swin_t: epoch 43/100 | train_acc=0.793 | val_acc=0.892
# swin_t: epoch 44/100 | train_acc=0.833 | val_acc=0.883
# swin_t: epoch 45/100 | train_acc=0.804 | val_acc=0.892
# swin_t: epoch 46/100 | train_acc=0.785 | val_acc=0.905
# swin_t: epoch 47/100 | train_acc=0.795 | val_acc=0.896
# swin_t: epoch 48/100 | train_acc=0.829 | val_acc=0.887
# swin_t: epoch 49/100 | train_acc=0.789 | val_acc=0.905
# swin_t: epoch 50/100 | train_acc=0.818 | val_acc=0.896
# swin_t: epoch 51/100 | train_acc=0.814 | val_acc=0.887
# swin_t: epoch 52/100 | train_acc=0.802 | val_acc=0.910
# swin_t: epoch 53/100 | train_acc=0.806 | val_acc=0.901
# swin_t: epoch 54/100 | train_acc=0.808 | val_acc=0.901
# swin_t: epoch 55/100 | train_acc=0.810 | val_acc=0.901
# swin_t: epoch 56/100 | train_acc=0.810 | val_acc=0.910
# swin_t: epoch 57/100 | train_acc=0.822 | val_acc=0.896
# swin_t: epoch 58/100 | train_acc=0.800 | val_acc=0.914
# swin_t: epoch 59/100 | train_acc=0.820 | val_acc=0.910
# swin_t: epoch 60/100 | train_acc=0.798 | val_acc=0.905
# swin_t: epoch 61/100 | train_acc=0.835 | val_acc=0.914
# swin_t: epoch 62/100 | train_acc=0.829 | val_acc=0.910
# swin_t: epoch 63/100 | train_acc=0.810 | val_acc=0.914
# swin_t: epoch 64/100 | train_acc=0.824 | val_acc=0.901
# swin_t: epoch 65/100 | train_acc=0.806 | val_acc=0.905
# swin_t: epoch 66/100 | train_acc=0.824 | val_acc=0.905
# swin_t: epoch 67/100 | train_acc=0.812 | val_acc=0.910
# swin_t: epoch 68/100 | train_acc=0.816 | val_acc=0.905
# swin_t: epoch 69/100 | train_acc=0.828 | val_acc=0.869
# swin_t: epoch 70/100 | train_acc=0.816 | val_acc=0.901
# swin_t: epoch 71/100 | train_acc=0.835 | val_acc=0.901
# swin_t: epoch 72/100 | train_acc=0.800 | val_acc=0.910
# swin_t: epoch 73/100 | train_acc=0.839 | val_acc=0.905
# swin_t: epoch 74/100 | train_acc=0.797 | val_acc=0.896
# swin_t: epoch 75/100 | train_acc=0.798 | val_acc=0.896
# swin_t: epoch 76/100 | train_acc=0.818 | val_acc=0.905
# swin_t: epoch 77/100 | train_acc=0.826 | val_acc=0.892
# swin_t: epoch 78/100 | train_acc=0.814 | val_acc=0.896
# swin_t: epoch 79/100 | train_acc=0.841 | val_acc=0.905
# swin_t: epoch 80/100 | train_acc=0.791 | val_acc=0.905
# swin_t: epoch 81/100 | train_acc=0.826 | val_acc=0.905
# swin_t: epoch 82/100 | train_acc=0.841 | val_acc=0.896
# swin_t: epoch 83/100 | train_acc=0.802 | val_acc=0.905
# swin_t: epoch 84/100 | train_acc=0.835 | val_acc=0.914
# swin_t: epoch 85/100 | train_acc=0.818 | val_acc=0.914
# swin_t: epoch 86/100 | train_acc=0.822 | val_acc=0.919
# swin_t: epoch 87/100 | train_acc=0.828 | val_acc=0.905
# swin_t: epoch 88/100 | train_acc=0.853 | val_acc=0.914
# swin_t: epoch 89/100 | train_acc=0.812 | val_acc=0.910
# swin_t: epoch 90/100 | train_acc=0.822 | val_acc=0.910
# swin_t: epoch 91/100 | train_acc=0.828 | val_acc=0.914
# swin_t: epoch 92/100 | train_acc=0.862 | val_acc=0.914
# swin_t: epoch 93/100 | train_acc=0.831 | val_acc=0.910
# swin_t: epoch 94/100 | train_acc=0.847 | val_acc=0.910
# swin_t: epoch 95/100 | train_acc=0.843 | val_acc=0.910
# swin_t: epoch 96/100 | train_acc=0.841 | val_acc=0.914
# swin_t: epoch 97/100 | train_acc=0.837 | val_acc=0.914
# swin_t: epoch 98/100 | train_acc=0.833 | val_acc=0.914
# swin_t: epoch 99/100 | train_acc=0.851 | val_acc=0.914
# swin_t: epoch 100/100 | train_acc=0.847 | val_acc=0.910
# swin_t: parameters=27,522,430, accuracy=91.892%, training=2493.872s, classification=0.018635s/image

# %%
{key: result[key] for key in (
    'parameter_count',
    'accuracy_percent',
    'training_time_seconds',
    'classification_time_seconds_per_image',
)}
# Out:
# {'parameter_count': 27522430,
#  'accuracy_percent': 91.8918918918919,
#  'training_time_seconds': 2493.872156,
#  'classification_time_seconds_per_image': 0.018634629}
